# %%
import pandas as pd
import re

# %%
text = "I love      123    ,,..   this 4565 movie"

# keep letters + apostrophes (for words like "don't"), replace others with space
text = re.sub(r"[^A-Za-z\s']", " ", text)


text = re.sub(r"\s+", " ", text)

text
# Out:
# 'I love this movie'

# %%
text = "My name is tapajit \n I am PhD Student \n Bye          "
print(text)

text = re.sub(r"\s+", " ", text)
print(text)

text = text.strip()
print(text)

text = text.lower()
print(text)
# Out:
# My name is tapajit
#  I am PhD Student
#  Bye
# My name is tapajit I am PhD Student Bye
# My name is tapajit I am PhD Student Bye
# my name is tapajit i am phd student bye
