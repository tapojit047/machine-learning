# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
my_list = [10, 20, 30]
arr = np.array([10, 20, 30])
d = {'a':10, 'b':20, 'c':30}

# %%
pd.Series(data=my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_list, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(arr,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series([sum,print,len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
ser1 = pd.Series([1,2,3,4],index=['USA','Germany','USSR','Japan'])
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2 = pd.Series(data = [1,2,5,4],index = ['USA', 'Germany','Italy', 'Japan'])
ser2
# Out:
# USA        1
# Germany    2
# Italy      5
# Japan      4
# dtype: int64

# %%
ser1+ser2
# Out:
# Germany    4.0
# Italy      NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64

# %%
data = {
    "Name": ["Alice", "Bob"],
    "Age": [25, 30]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
'A B C D E'.split() # split() turns string into an array
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A  0.754948  1.383007 -0.583494 -0.206557
# B -0.221307 -0.924255 -0.552820  1.088777
# C -0.552738  1.042145 -2.537231  0.464764
# D -0.861387  0.772970 -0.598536 -0.629138
# E -0.982428  2.059603  0.622693 -1.526475

# %%
df['W']
# Out:
# A    0.754948
# B   -0.221307
# C   -0.552738
# D   -0.861387
# E   -0.982428
# Name: W, dtype: float64

# %%
df[['W','Z']]
# Out:
#           W         Z
# A  0.754948 -0.206557
# B -0.221307  1.088777
# C -0.552738  0.464764
# D -0.861387 -0.629138
# E -0.982428 -1.526475

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
df['new']=df['W'] + df['Y']
df
# Out:
#           W         X         Y         Z       new
# A  0.754948  1.383007 -0.583494 -0.206557  0.171454
# B -0.221307 -0.924255 -0.552820  1.088777 -0.774128
# C -0.552738  1.042145 -2.537231  0.464764 -3.089969
# D -0.861387  0.772970 -0.598536 -0.629138 -1.459923
# E -0.982428  2.059603  0.622693 -1.526475 -0.359735

# %%
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z
# A  0.754948  1.383007 -0.583494 -0.206557
# B -0.221307 -0.924255 -0.552820  1.088777
# C -0.552738  1.042145 -2.537231  0.464764
# D -0.861387  0.772970 -0.598536 -0.629138
# E -0.982428  2.059603  0.622693 -1.526475

# %%
df # Because we did not assign it
# Out:
#           W         X         Y         Z       new
# A  0.754948  1.383007 -0.583494 -0.206557  0.171454
# B -0.221307 -0.924255 -0.552820  1.088777 -0.774128
# C -0.552738  1.042145 -2.537231  0.464764 -3.089969
# D -0.861387  0.772970 -0.598536 -0.629138 -1.459923
# E -0.982428  2.059603  0.622693 -1.526475 -0.359735

# %%
df.drop('new',axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A  0.754948  1.383007 -0.583494 -0.206557
# B -0.221307 -0.924255 -0.552820  1.088777
# C -0.552738  1.042145 -2.537231  0.464764
# D -0.861387  0.772970 -0.598536 -0.629138
# E -0.982428  2.059603  0.622693 -1.526475

# %%
df.drop('E',axis=0)
# Out:
#           W         X         Y         Z
# A  0.754948  1.383007 -0.583494 -0.206557
# B -0.221307 -0.924255 -0.552820  1.088777
# C -0.552738  1.042145 -2.537231  0.464764
# D -0.861387  0.772970 -0.598536 -0.629138

# %%
df.loc['A']
# Out:
# W    0.754948
# X    1.383007
# Y   -0.583494
# Z   -0.206557
# Name: A, dtype: float64

# %%
df.iloc[2]
# Out:
# W   -0.552738
# X    1.042145
# Y   -2.537231
# Z    0.464764
# Name: C, dtype: float64

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A  0.754948 -0.583494
# B -0.221307 -0.552820

# %%
df = pd.DataFrame({'A':[1,2,np.nan],
                   'B':[5,np.nan,np.nan],
                   'C':[1,2,3]})
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
data= pd.read_csv('./data_files/sample_data.csv')
data
# Out:
#    Age gender
# 0   32      F
# 1   14      F
# 2   72      M
# 3   37      F
# 4   21      M

# %%
data.head()
# Out:
#    Age gender
# 0   32      F
# 1   14      F
# 2   72      M
# 3   37      F
# 4   21      M

# %%
data.shape
# Out:
# (5, 2)

# %%
data.values
# Out:
# array([[32, 'F'],
#        [14, 'F'],
#        [72, 'M'],
#        [37, 'F'],
#        [21, 'M']], dtype=object)

# %%
data=pd.read_csv('./data_files/sample_data_no_header.csv')

# %%
data
# Out:
#    32  F
# 0  14  F
# 1  72  M
# 2  37  F
# 3  21  M

# %%
data.shape
# Out:
# (4, 2)

# %%
data=pd.read_csv('./data_files/sample_data_no_header.csv',header=None)
data
# Out:
#     0  1
# 0  32  F
# 1  14  F
# 2  72  M
# 3  37  F
# 4  21  M

# %%
data = pd.read_csv('./data_files/test.txt')
data
# Out:
#    17   M
# 0  23   F
# 1  12   M
# 2  24   M
# 3  56   F

# %%
data.to_csv('output_data.csv',header=False,index=None)
